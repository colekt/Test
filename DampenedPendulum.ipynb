# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
# %matplotlib inline

# %%
#Initialize 
t0 = 0
tf = 45
#figure out how to make this in periods or 1/w
N = 100
dt = (tf-t0)/N
theta_0 = .2
vel_init = 0
visc = 1
A = 1.5
womega = 2/3

# %%
def rk4(x1_0,x2_0,time,dt,func1,func2):
    k11 = dt*func1(x1_0,x2_0,time)
    k12 = dt*func2(x1_0,x2_0,time)
    k21 = dt*func1(x1_0 + k11*.5,x2_0 + k12*.5,time+dt*.5)
    k22 = dt*func2(x1_0 + k11*.5,x2_0 + k12*.5,time+dt*.5)
    k31 = dt*func1(x1_0 + k21*.5,x2_0 + k22*.5,time+dt*.5)
    k32 = dt*func2(x1_0 + k21*.5,x2_0 + k22*.5,time+dt*.5)
    k41 = dt*func1(x1_0 + k31,x2_0 + k32,time + dt)
    k42 = dt*func2(x1_0 + k31,x2_0 + k32,time + dt)
    x1_1 = x1_0 + (1/6.0)*(k11+k21+k31+k41)
    x2_1 = x2_0 + (1/6.0)*(k12+k22+k32+k42)
    return (x1_1,x2_1)

# %%
def rungekuttafunc(viscosity,Netpoints):
    #Initialize 
    t0 = 0
    tf = 100
    #figure out how to make this in periods or 1/w
    N = Netpoints
    timestep = (tf-t0)/N
    theta_0 = .2
    vel_init = 0
    #define functions for going into rk4
    def velocity(x1,x2,t):
        return x2
    def acceleration(x1,x2,t):
        return -viscosity*x2-np.sin(x1)
    #run rk4
    t = np.arange(0.0,tf,timestep)
    state = np.zeros((N,2))
    state[0,0], state[0,1] = theta_0, vel_init
    for i in range(N-1):
        state[i+1,0],state[i+1,1] = rk4(state[i,0],state[i,1],t[i],timestep,velocity,acceleration)
    #plot 
    ax = plt.figure()
    #pos vs time
    plt.subplot(121)
    plt.plot(t,state[:,0])
    plt.title("Time vs. Angle")
    plt.ylabel("Angle (rad)")
    plt.xlabel("Time (sec)")
    #velocity vs time
    plt.subplot(122)
    plt.plot(state[:,0],state[:,1])
    plt.title("Angle vs. Velocity")
    plt.ylabel("Velocity (rad/sec)")
    plt.xlabel("Angle (rad)")
    plt.subplots_adjust(wspace = .5)
    ax.set_figwidth(15)
    ax.suptitle("Viscosity: " + str(viscosity) + "  Meshpoints: " + str(Netpoints), fontsize=10)
    plt.show()

# %%
def eulerfunc(viscosity,Netpoints):
    #Initialize 
    t0 = 0
    tf = 100
    #figure out how to make this in periods or 1/w
    N = Netpoints
    dt = (tf-t0)/N
    theta_0 = .2
    vel_init = 0
    visc = viscosity
    #make the empty vectors
    t = np.arange(0.0,tf,dt)
    r = np.zeros(len(t))
    v = np.zeros(len(t))
    a = np.zeros(len(t))
    #set initial conditions
    r[0] = theta_0
    v[0] = vel_init
    a[0] = -np.sin(r[0])-v[0]*(visc)
    #euler cromer babyyy
    for i in range(len(t)-1):
        a[i+1] = -np.sin(r[i])-v[i]*(visc)
        v[i+1] = v[i]+dt*a[i]
        r[i+1] = r[i]+dt*v[i+1]
    #plot 
    ax = plt.figure()
    #pos vs time
    plt.subplot(121)
    plt.plot(t,r)
    plt.title("Time vs. Angle")
    plt.ylabel("Angle (rad)")
    plt.xlabel("Time (sec)")
    #velocity vs time
    plt.subplot(122)
    plt.plot(r,v)
    plt.title("Angle vs. Velocity")
    plt.ylabel("Velocity (rad/sec)")
    plt.xlabel("Angle (rad)")
    plt.subplots_adjust(wspace = .5)
    ax.set_figwidth(15)
    ax.suptitle("Viscosity: " + str(viscosity) + "  Meshpoints: " + str(Netpoints), fontsize=10)
    plt.show()

# %%
eulerfunc(.15,100)

# %%
rungekuttafunc(.15,100)

# %%
eulerfunc(.15,1000)

# %%
rungekuttafunc(.15,1000)

# %%
eulerfunc(.15,10000)

# %%
rungekuttafunc(.15,10000)

# %%
eulerfunc(2,100)

# %%
rungekuttafunc(2,100)

# %%
eulerfunc(2,1000)

# %%
rungekuttafunc(2,1000)

# %%
eulerfunc(2,10000)

# %%
rungekuttafunc(2,10000)

# %%
eulerfunc(5,100)

# %%
rungekuttafunc(5,100)

# %%
eulerfunc(5,1000)

# %%
rungekuttafunc(5,1000)

# %%
eulerfunc(5,10000)

# %%
rungekuttafunc(5,10000)

# %%
#messing around with poincaire sections
psec = np.zeros(len(t))
for i in range(len(r)):
    if ((womega*t[i] <= (2*3.14))):
        psec[i] = r[i]
ax = plt.scatter(v,psec, s = 1)
#ax = plt.plot(markersize = 1)
#plt.scatter(v,psec, MarkerStyle = ".")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-42-156f2284b478> in <module>
#       1 #messing around with poincaire sections
# ----> 2 psec = np.zeros(len(t))
#       3 for i in range(len(r)):
#       4     if ((womega*t[i] <= (2*3.14))):
#       5         psec[i] = r[i]
#
# NameError: name 't' is not defined

# %%
# Out:
# 0.03
